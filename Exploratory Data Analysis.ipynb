# %%
#Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load Dataset
df = pd.read_csv("Cleaned_EV_Registration_Dataset.csv")
df
# Out:
#         Unnamed: 0  Identifier           City  Postal Code  Model Year  \
# 0                0  KL8CL6S05E         Tacoma      98407.0        2014
# 1                1  JTDKARFP0H  Port Townsend      98368.0        2017
# 2                2  JHMZC5F34J         Vashon      98070.0        2018
# 3                3  KMHC65LD0K     Ridgefield      98642.0        2019
# 4                4  1N4AZ1CP6J      Bremerton      98337.0        2018
# ...            ...         ...            ...          ...         ...
# 134469      135033  JTDKARFP0H   Port Angeles      98362.0        2017
# 134470      135034  5YJ3E1EB7L        Seattle      98134.0        2020
# 134471      135035  7FCTGAAL4N         Renton      98059.0        2022
# 134472      135036  WVGGNPE28N     Bellingham      98225.0        2022
# 134473      135037  2C4RC1N70L        Seattle      98126.0        2020
#
#               Make        Model                   Electric Vehicle Type  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  Identifier          City  Postal Code  Model Year  \
# 134469      135033  JTDKARFP0H  Port Angeles      98362.0        2017
# 134470      135034  5YJ3E1EB7L       Seattle      98134.0        2020
# 134471      135035  7FCTGAAL4N        Renton      98059.0        2022
# 134472      135036  WVGGNPE28N    Bellingham      98225.0        2022
# 134473      135037  2C4RC1N70L       Seattle      98126.0        2020
#
#               Make        Model                   Electric Vehicle Type  \
# 134469      TOYOTA  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 134470       TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 134471      RIVIAN          R1T          Battery Electric Vehicle (BEV)
# 134472  VOLKSWAGEN         ID.4          Battery Electric Vehicle (BEV)
# 134473    CHRYSLER     PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
# showing dataset shape
df.shape
# Out:
# (134474, 16)

# %%
# cheking columns names
df.columns
# Out:
# Index(['Unnamed: 0', 'Identifier', 'City', 'Postal Code', 'Model Year', 'Make',
#        'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'Vehicle ID', 'Vehicle Location',
#        'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
# describing dataset
df.describe()
# Out:
#           Unnamed: 0    Postal Code     Model Year  Electric Range  \
# count  134474.000000  134474.000000  134474.000000   134474.000000
# mean    67515.378869   98259.228520    2019.657250       74.730208
# std     38985.966756     303.069045       3.001443       98.776037
# min         0.000000   98001.000000    1997.000000        0.000000
# 25%     33751.250000   98052.000000    2018.000000        0.000000
# 50%     67521.500000   98122.000000    2021.000000       21.000000
# 75%    101277.750000   98370.000000    2022.000000      150.000000
# max    135037.000000   99403.000000    2024.000000      337.000000
#
#            Base MSRP  Legislative District    Vehicle ID  2020 Census Tract
# count  134474.000000         134474.000000  1.344740e+05       1.344740e+05
# mean     1451.396069             29.499911  2.063218e+08       5.303964e+10
# std      9691.900720             14.786294  8.590842e+07       1.617660e+07
# ...

# %%
# check for unique values
df.nunique()
# Out:
# Unnamed: 0                                           134474
# Identifier                                             9017
# City                                                    454
# Postal Code                                             530
# Model Year                                               22
# Make                                                     36
# Model                                                   125
# Electric Vehicle Type                                     2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility         3
# Electric Range                                          102
# Base MSRP                                                31
# Legislative District                                     49
# Vehicle ID                                           134474
# Vehicle Location                                        530
# Electric Utility                                         75
# 2020 Census Tract                                      1765
# ...

# %%
# plotting heatmap
correlation = df.corr()
# Out:
# /tmp/ipykernel_468/421964948.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.relplot(x= 'Model Year', y= 'Electric Range' ,hue='Electric Vehicle Type', data = df)

# %%
sns.relplot(x= 'Model Year', y= 'Electric Range' ,hue='Make', data = df)

# %%
sns.distplot(df['Model Year'])
# Out:
# /tmp/ipykernel_468/3537491718.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Model Year'])
# <AxesSubplot: xlabel='Model Year', ylabel='Density'>

# %%
sns.distplot(df['Electric Range'])
# Out:
# /tmp/ipykernel_468/3057903075.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Electric Range'])
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
sns.distplot(df['Legislative District'])
# Out:
# /tmp/ipykernel_368/3243344363.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Legislative District'])
# <AxesSubplot: xlabel='Legislative District', ylabel='Density'>

# %%
sns.catplot(x='Electric Range', kind='box', data=df)

# %%
sns.catplot(x='Legislative District', kind='box', data=df)
